# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# data transformation/preparation
df = pd.read_csv('block_9_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   timestamp       151254 non-null  object
#  1   asin            151254 non-null  object
#  2   helpful         151254 non-null  object
#  3   overall         151254 non-null  float64
#  4   reviewText      151232 non-null  object
#  5   reviewTime      151254 non-null  object
#  6   reviewerID      151254 non-null  object
#  7   reviewerName    149761 non-null  object
#  8   summary         151254 non-null  object
#  9   unixReviewTime  151254 non-null  int64
#  10  review_year     151254 non-null  int64
#  11  review_month    151254 non-null  int64
#  12  review_day      151254 non-null  int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 15.0+ MB

# %%
df.head()
# Out:
#     timestamp        asin helpful  overall  \
# 0  2013-06-01  616719923X  [0, 0]      4.0
# 1  2014-05-19  616719923X  [0, 1]      3.0
# 2  2013-10-08  616719923X  [3, 4]      4.0
# 3  2013-05-20  616719923X  [0, 0]      5.0
# 4  2013-05-26  616719923X  [1, 2]      4.0
#
#                                           reviewText   reviewTime  \
# 0  Just another flavor of Kit Kat but the taste i...   06 1, 2013
# 1  I bought this on impulse and it comes from Jap...  05 19, 2014
# 2  Really good. Great gift for any fan of green t...   10 8, 2013
# 3  I had never had it before, was curious to see ...  05 20, 2013
# 4  I've been looking forward to trying these afte...  05 26, 2013
#
#        reviewerID     reviewerName  \
# 0  A1VEELTKS8NLZB  Amazon Customer
# 1  A14R9XMZVJ6INB          amf0001
# 2  A27IQHDZFQFNGG          Caitlin
# 3  A31QY5TASILE89     DebraDownSth
# 4  A2LWK003FFMCI5         Diana X.
#
#                                              summary  unixReviewTime  \
# 0                                         Good Taste      1370044800
# 1  3.5 stars,  sadly not as wonderful as I had hoped      1400457600
# 2                                               Yum!      1381190400
# 3                             Unexpected flavor meld      1369008000
# 4  Not a very strong tea flavor, but still yummy ...      1369526400
#
#    review_year  review_month  review_day
# 0         2013             6           1
# 1         2014             5          19
# 2         2013            10           8
# 3         2013             5          20
# 4         2013             5          26

# %% [markdown]
# $ rating = \alpha + \beta_{1} * reviews + \beta_{2} * avaerage + u $

# %%
# weight 
df.loc[:, 'weight'] = 1

# %%
# set index
# 重新设置以 asin 开头的 index 因为很多数据都包含着相同的 asin
df.set_index(['asin', 'review_year', 'review_month', 'review_day'], inplace=True)

# %%
df.head().T
# Out:
# asin                                                   616719923X  \
# review_year                                                  2013
# review_month                                                   6
# review_day                                                     1
# timestamp                                              2013-06-01
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# weight                                                          1
#
# asin                                                               \
# review_year                                                  2014
# review_month                                                   5
# review_day                                                     19
# timestamp                                              2014-05-19
# helpful                                                    [0, 1]
# overall                                                       3.0
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# weight                                                          1
#
# asin                                                               \
# review_year                                                  2013
# review_month                                                   10
# review_day                                                     8
# timestamp                                              2013-10-08
# helpful                                                    [3, 4]
# overall                                                       4.0
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# weight                                                          1
#
# asin                                                               \
# review_year
# review_month                                                   5
# review_day                                                     20
# timestamp                                              2013-05-20
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# weight                                                          1
#
# asin
# review_year
# review_month
# review_day                                                     26
# timestamp                                              2013-05-26
# helpful                                                    [1, 2]
# overall                                                       4.0
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# weight                                                          1

# %%
df.loc[:,'reviews'] = df.groupby(level=['asin'])['weight'].transform(np.cumsum)

# %%
df.T
# Out:
# asin                                                   616719923X  \
# review_year                                                  2013
# review_month                                                   6
# review_day                                                     1
# timestamp                                              2013-06-01
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# weight                                                          1
# reviews                                                         1
#
# asin                                                               \
# review_year                                                  2014
# review_month                                                   5
# review_day                                                     19
# timestamp                                              2014-05-19
# helpful                                                    [0, 1]
# overall                                                       3.0
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# weight                                                          1
# reviews                                                         2
#
# asin                                                               \
# review_year                                                  2013
# review_month                                                   10
# review_day                                                     8
# timestamp                                              2013-10-08
# helpful                                                    [3, 4]
# overall                                                       4.0
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# weight                                                          1
# reviews                                                         3
#
# asin                                                               \
# review_year
# review_month                                                   5
# review_day                                                     20
# timestamp                                              2013-05-20
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# weight                                                          1
# reviews                                                         4
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     26
# timestamp                                              2013-05-26
# helpful                                                    [1, 2]
# overall                                                       4.0
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# weight                                                          1
# reviews                                                         5
#
# asin                                                               \
# review_year
# review_month                                                   9
# review_day                                                     5
# timestamp                                              2013-09-05
# helpful                                                    [0, 1]
# overall                                                       4.0
# reviewText      These Kit-kats are very good, but if you're lo...
# reviewTime                                             09 5, 2013
# reviewerID                                         A1NZJTY0BAA2SK
# reviewerName                                            Elizabeth
# summary                                                    Subtle
# unixReviewTime                                         1378339200
# weight                                                          1
# reviews                                                         6
#
# asin                                                               \
# review_year
# review_month                                                   10
# review_day                                                     18
# timestamp                                              2013-10-18
# helpful                                                    [1, 2]
# overall                                                       3.0
# reviewText      I found these in a Mitsuwa Marketplace in Illi...
# reviewTime                                            10 18, 2013
# reviewerID                                          AA95FYFIP38RM
# reviewerName                      Emily Veinglory "Book Reviewer"
# summary                               Available in some US stores
# unixReviewTime                                         1382054400
# weight                                                          1
# reviews                                                         7
#
# asin                                                               \
# review_year
# review_month                                                   7
# review_day                                                     5
# timestamp                                              2013-07-05
# helpful                                                    [2, 3]
# overall                                                       5.0
# reviewText      Creamy white chocolate infused with Matcha gre...
# reviewTime                                             07 5, 2013
# reviewerID                                         A3FIVHUOGMUMPK
# reviewerName                                            greenlife
# summary                                            So Delicious!!
# unixReviewTime                                         1372982400
# weight                                                          1
# reviews                                                         8
#
# asin                                                               \
# review_year
# review_month                                                   6
# review_day                                                     14
# timestamp                                              2013-06-14
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      After hearing mixed opinions about these Kit K...
# reviewTime                                            06 14, 2013
# reviewerID                                         A27FSPAMTQF1J8
# reviewerName                                               Japhyl
# summary                       These are my favorite candies ever!
# unixReviewTime                                         1371168000
# weight                                                          1
# reviews                                                         9
#
# asin                                                               ...  \
# review_year                                                  2012  ...
# review_month                                                   9   ...
# review_day                                                     19  ...
# timestamp                                              2012-09-19  ...
# helpful                                                   [0, 10]  ...
# overall                                                       1.0  ...
# reviewText      I love green tea, I love Kit Kats, but the two...  ...
# reviewTime                                            09 19, 2012  ...
# reviewerID                                         A33NXNZ79H5K51  ...
# reviewerName                                          Jean M "JM"  ...
# summary                                                 Not a fan  ...
# unixReviewTime                                         1348012800  ...
# weight                                                          1  ...
# reviews                                                        10  ...
#
# asin                                                   B00KCJRVO2  \
# review_year                                                  2014
# review_month                                                   7
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [1, 1]
# overall                                                       5.0
# reviewText      A lot of these quick oatmeal products don't ma...
# reviewTime                                             07 6, 2014
# reviewerID                                         A11T807LX2EF00
# reviewerName                                              Michael
# summary         Easy to make and the taste is quite good. Exce...
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        14
#
# asin                                                               \
# review_year
# review_month                                                   6
# review_day                                                     30
# timestamp                                              2014-06-30
# helpful                                                    [0, 0]
# overall                                                       3.0
# reviewText      When it has came down to General Mills, they h...
# reviewTime                                            06 30, 2014
# reviewerID                                         A3W4D8XOGLWUN5
# reviewerName                      Michael Kerner "Michael Kerner"
# summary                                     Oatmeal, But Not More
# unixReviewTime                                         1404086400
# weight                                                          1
# reviews                                                        15
#
# asin                                                               \
# review_year
# review_month                                                   7
# review_day                                                     21
# timestamp                                              2014-07-21
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      My daughter thinks it tastes just like the reg...
# reviewTime                                            07 21, 2014
# reviewerID                                         A3H0ZQ74ITU83J
# reviewerName                                      Mom and Teacher
# summary                                           Thank you Chex!
# unixReviewTime                                         1405900800
# weight                                                          1
# reviews                                                        16
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     2
# timestamp                                              2014-07-02
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      It may seem surprising to see an oatmeal produ...
# reviewTime                                             07 2, 2014
# reviewerID                                         A3RJR9UL7HEROC
# reviewerName                                         Phelps Gates
# summary         Would have liked more information on gluten pr...
# unixReviewTime                                         1404259200
# weight                                                          1
# reviews                                                        17
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I like oatmeal and will often make a pot of Mc...
# reviewTime                                             07 6, 2014
# reviewerID                                          A3VYKXHQDICC6
# reviewerName                                          philo_vance
# summary                                                 Excellent
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        18
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     12
# timestamp                                              2014-07-12
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Delicious gluten-free oatmeal: we tried both t...
# reviewTime                                            07 12, 2014
# reviewerID                                         A2L6QS8SVHT9RG
# reviewerName                 randomartco "period film aficionado"
# summary              Delicious gluten-free oatmeal 'quick' packs!
# unixReviewTime                                         1405123200
# weight                                                          1
# reviews                                                        19
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      With the many selections of instant oatmeal ce...
# reviewTime                                             07 6, 2014
# reviewerID                                          AFJFXN42RZ3G2
# reviewerName                                  R. DelParto "Rose2"
# summary                                    Convenient and Instant
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        20
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     1
# timestamp                                              2014-07-01
# helpful                                                    [1, 1]
# overall                                                       5.0
# reviewText      While I usually review CDs and DVDs, as well a...
# reviewTime                                             07 1, 2014
# reviewerID                                          ASEBX8TBYWQWA
# reviewerName     Steven I. Ramm "Steve Ramm &#34;Anything Phon...
# summary         Compares favorably in taste and texture with o...
# unixReviewTime                                         1404172800
# weight                                                          1
# reviews                                                        21
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     4
# timestamp                                              2014-07-04
# helpful                                                    [0, 1]
# overall                                                       4.0
# reviewText      My son and I enjoyed these oatmeal packets.  H...
# reviewTime                                             07 4, 2014
# reviewerID                                          ANKQGTXHREOI5
# reviewerName                                        Titanium Lili
# summary                                              Pretty good!
# unixReviewTime                                         1404432000
# weight                                                          1
# reviews                                                        22
#
# asin
# review_year
# review_month
# review_day                                                     11
# timestamp                                              2014-07-11
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      I like to eat oatmeal i the mornings. I usuall...
# reviewTime                                            07 11, 2014
# reviewerID                                         A2CF66KIQ3RKX3
# reviewerName                                         Vivian Deliz
# summary                      I like to eat oatmeal i the mornings
# unixReviewTime                                         1405036800
# weight                                                          1
# reviews                                                        23
#
# [11 rows x 151254 columns]

# %%
# 算出每个对于商品review的平均值
df.loc[:, 'average'] = df.groupby(level=['asin'])['overall'].transform(np.cumsum)
df.loc[:, 'average'] = df['average'] / df['reviews']
df.T
# Out:
# asin                                                   616719923X  \
# review_year                                                  2013
# review_month                                                   6
# review_day                                                     1
# timestamp                                              2013-06-01
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# weight                                                          1
# reviews                                                         1
# average                                                       4.0
#
# asin                                                               \
# review_year                                                  2014
# review_month                                                   5
# review_day                                                     19
# timestamp                                              2014-05-19
# helpful                                                    [0, 1]
# overall                                                       3.0
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# weight                                                          1
# reviews                                                         2
# average                                                       3.5
#
# asin                                                               \
# review_year                                                  2013
# review_month                                                   10
# review_day                                                     8
# timestamp                                              2013-10-08
# helpful                                                    [3, 4]
# overall                                                       4.0
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# weight                                                          1
# reviews                                                         3
# average                                                  3.666667
#
# asin                                                               \
# review_year
# review_month                                                   5
# review_day                                                     20
# timestamp                                              2013-05-20
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# weight                                                          1
# reviews                                                         4
# average                                                       4.0
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     26
# timestamp                                              2013-05-26
# helpful                                                    [1, 2]
# overall                                                       4.0
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# weight                                                          1
# reviews                                                         5
# average                                                       4.0
#
# asin                                                               \
# review_year
# review_month                                                   9
# review_day                                                     5
# timestamp                                              2013-09-05
# helpful                                                    [0, 1]
# overall                                                       4.0
# reviewText      These Kit-kats are very good, but if you're lo...
# reviewTime                                             09 5, 2013
# reviewerID                                         A1NZJTY0BAA2SK
# reviewerName                                            Elizabeth
# summary                                                    Subtle
# unixReviewTime                                         1378339200
# weight                                                          1
# reviews                                                         6
# average                                                       4.0
#
# asin                                                               \
# review_year
# review_month                                                   10
# review_day                                                     18
# timestamp                                              2013-10-18
# helpful                                                    [1, 2]
# overall                                                       3.0
# reviewText      I found these in a Mitsuwa Marketplace in Illi...
# reviewTime                                            10 18, 2013
# reviewerID                                          AA95FYFIP38RM
# reviewerName                      Emily Veinglory "Book Reviewer"
# summary                               Available in some US stores
# unixReviewTime                                         1382054400
# weight                                                          1
# reviews                                                         7
# average                                                  3.857143
#
# asin                                                               \
# review_year
# review_month                                                   7
# review_day                                                     5
# timestamp                                              2013-07-05
# helpful                                                    [2, 3]
# overall                                                       5.0
# reviewText      Creamy white chocolate infused with Matcha gre...
# reviewTime                                             07 5, 2013
# reviewerID                                         A3FIVHUOGMUMPK
# reviewerName                                            greenlife
# summary                                            So Delicious!!
# unixReviewTime                                         1372982400
# weight                                                          1
# reviews                                                         8
# average                                                       4.0
#
# asin                                                               \
# review_year
# review_month                                                   6
# review_day                                                     14
# timestamp                                              2013-06-14
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      After hearing mixed opinions about these Kit K...
# reviewTime                                            06 14, 2013
# reviewerID                                         A27FSPAMTQF1J8
# reviewerName                                               Japhyl
# summary                       These are my favorite candies ever!
# unixReviewTime                                         1371168000
# weight                                                          1
# reviews                                                         9
# average                                                  4.111111
#
# asin                                                               ...  \
# review_year                                                  2012  ...
# review_month                                                   9   ...
# review_day                                                     19  ...
# timestamp                                              2012-09-19  ...
# helpful                                                   [0, 10]  ...
# overall                                                       1.0  ...
# reviewText      I love green tea, I love Kit Kats, but the two...  ...
# reviewTime                                            09 19, 2012  ...
# reviewerID                                         A33NXNZ79H5K51  ...
# reviewerName                                          Jean M "JM"  ...
# summary                                                 Not a fan  ...
# unixReviewTime                                         1348012800  ...
# weight                                                          1  ...
# reviews                                                        10  ...
# average                                                       3.8  ...
#
# asin                                                   B00KCJRVO2  \
# review_year                                                  2014
# review_month                                                   7
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [1, 1]
# overall                                                       5.0
# reviewText      A lot of these quick oatmeal products don't ma...
# reviewTime                                             07 6, 2014
# reviewerID                                         A11T807LX2EF00
# reviewerName                                              Michael
# summary         Easy to make and the taste is quite good. Exce...
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        14
# average                                                  4.571429
#
# asin                                                               \
# review_year
# review_month                                                   6
# review_day                                                     30
# timestamp                                              2014-06-30
# helpful                                                    [0, 0]
# overall                                                       3.0
# reviewText      When it has came down to General Mills, they h...
# reviewTime                                            06 30, 2014
# reviewerID                                         A3W4D8XOGLWUN5
# reviewerName                      Michael Kerner "Michael Kerner"
# summary                                     Oatmeal, But Not More
# unixReviewTime                                         1404086400
# weight                                                          1
# reviews                                                        15
# average                                                  4.466667
#
# asin                                                               \
# review_year
# review_month                                                   7
# review_day                                                     21
# timestamp                                              2014-07-21
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      My daughter thinks it tastes just like the reg...
# reviewTime                                            07 21, 2014
# reviewerID                                         A3H0ZQ74ITU83J
# reviewerName                                      Mom and Teacher
# summary                                           Thank you Chex!
# unixReviewTime                                         1405900800
# weight                                                          1
# reviews                                                        16
# average                                                       4.5
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     2
# timestamp                                              2014-07-02
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      It may seem surprising to see an oatmeal produ...
# reviewTime                                             07 2, 2014
# reviewerID                                         A3RJR9UL7HEROC
# reviewerName                                         Phelps Gates
# summary         Would have liked more information on gluten pr...
# unixReviewTime                                         1404259200
# weight                                                          1
# reviews                                                        17
# average                                                  4.470588
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I like oatmeal and will often make a pot of Mc...
# reviewTime                                             07 6, 2014
# reviewerID                                          A3VYKXHQDICC6
# reviewerName                                          philo_vance
# summary                                                 Excellent
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        18
# average                                                       4.5
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     12
# timestamp                                              2014-07-12
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Delicious gluten-free oatmeal: we tried both t...
# reviewTime                                            07 12, 2014
# reviewerID                                         A2L6QS8SVHT9RG
# reviewerName                 randomartco "period film aficionado"
# summary              Delicious gluten-free oatmeal 'quick' packs!
# unixReviewTime                                         1405123200
# weight                                                          1
# reviews                                                        19
# average                                                  4.473684
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     6
# timestamp                                              2014-07-06
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      With the many selections of instant oatmeal ce...
# reviewTime                                             07 6, 2014
# reviewerID                                          AFJFXN42RZ3G2
# reviewerName                                  R. DelParto "Rose2"
# summary                                    Convenient and Instant
# unixReviewTime                                         1404604800
# weight                                                          1
# reviews                                                        20
# average                                                      4.45
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     1
# timestamp                                              2014-07-01
# helpful                                                    [1, 1]
# overall                                                       5.0
# reviewText      While I usually review CDs and DVDs, as well a...
# reviewTime                                             07 1, 2014
# reviewerID                                          ASEBX8TBYWQWA
# reviewerName     Steven I. Ramm "Steve Ramm &#34;Anything Phon...
# summary         Compares favorably in taste and texture with o...
# unixReviewTime                                         1404172800
# weight                                                          1
# reviews                                                        21
# average                                                   4.47619
#
# asin                                                               \
# review_year
# review_month
# review_day                                                     4
# timestamp                                              2014-07-04
# helpful                                                    [0, 1]
# overall                                                       4.0
# reviewText      My son and I enjoyed these oatmeal packets.  H...
# reviewTime                                             07 4, 2014
# reviewerID                                          ANKQGTXHREOI5
# reviewerName                                        Titanium Lili
# summary                                              Pretty good!
# unixReviewTime                                         1404432000
# weight                                                          1
# reviews                                                        22
# average                                                  4.454545
#
# asin
# review_year
# review_month
# review_day                                                     11
# timestamp                                              2014-07-11
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      I like to eat oatmeal i the mornings. I usuall...
# reviewTime                                            07 11, 2014
# reviewerID                                         A2CF66KIQ3RKX3
# reviewerName                                         Vivian Deliz
# summary                      I like to eat oatmeal i the mornings
# unixReviewTime                                         1405036800
# weight                                                          1
# reviews                                                        23
# average                                                  4.434783
#
# [12 rows x 151254 columns]

# %% [markdown]
# ## OLS

# %%
fml = 'overall ~ reviews + average'
ols = smf.ols(fml, data=df).fit()

# %%
print(ols.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                 3.040e+04
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):               0.00
# Time:                        22:24:00   Log-Likelihood:            -2.0210e+05
# No. Observations:              151254   AIC:                         4.042e+05
# Df Residuals:                  151251   BIC:                         4.042e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0141      0.018     -0.773      0.440      -0.050       0.022
# reviews    -7.404e-05   3.29e-05     -2.250      0.024      -0.000   -9.55e-06
# average        1.0032      0.004    240.564      0.000       0.995       1.011
# ==============================================================================
# Omnibus:                    28401.591   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54895.281
# Skew:                          -1.153   Prob(JB):                         0.00
# Kurtosis:                       4.842   Cond. No.                         670.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df.head().T
# Out:
# asin                                                   616719923X  \
# review_year                                                  2013
# review_month                                                   6
# review_day                                                     1
# timestamp                                              2013-06-01
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# weight                                                          1
# reviews                                                         1
# average                                                       4.0
#
# asin                                                               \
# review_year                                                  2014
# review_month                                                   5
# review_day                                                     19
# timestamp                                              2014-05-19
# helpful                                                    [0, 1]
# overall                                                       3.0
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# weight                                                          1
# reviews                                                         2
# average                                                       3.5
#
# asin                                                               \
# review_year                                                  2013
# review_month                                                   10
# review_day                                                     8
# timestamp                                              2013-10-08
# helpful                                                    [3, 4]
# overall                                                       4.0
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# weight                                                          1
# reviews                                                         3
# average                                                  3.666667
#
# asin                                                               \
# review_year
# review_month                                                   5
# review_day                                                     20
# timestamp                                              2013-05-20
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# weight                                                          1
# reviews                                                         4
# average                                                       4.0
#
# asin
# review_year
# review_month
# review_day                                                     26
# timestamp                                              2013-05-26
# helpful                                                    [1, 2]
# overall                                                       4.0
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# weight                                                          1
# reviews                                                         5
# average                                                       4.0

# %% [markdown]
# ## robust regression

# %%
df.reset_index(inplace=True)
df.head().T
# Out:
#                                                                 0  \
# asin                                                   616719923X
# review_year                                                  2013
# review_month                                                    6
# review_day                                                      1
# timestamp                                              2013-06-01
# helpful                                                    [0, 0]
# overall                                                       4.0
# reviewText      Just another flavor of Kit Kat but the taste i...
# reviewTime                                             06 1, 2013
# reviewerID                                         A1VEELTKS8NLZB
# reviewerName                                      Amazon Customer
# summary                                                Good Taste
# unixReviewTime                                         1370044800
# weight                                                          1
# reviews                                                         1
# average                                                       4.0
#
#                                                                 1  \
# asin                                                   616719923X
# review_year                                                  2014
# review_month                                                    5
# review_day                                                     19
# timestamp                                              2014-05-19
# helpful                                                    [0, 1]
# overall                                                       3.0
# reviewText      I bought this on impulse and it comes from Jap...
# reviewTime                                            05 19, 2014
# reviewerID                                         A14R9XMZVJ6INB
# reviewerName                                              amf0001
# summary         3.5 stars,  sadly not as wonderful as I had hoped
# unixReviewTime                                         1400457600
# weight                                                          1
# reviews                                                         2
# average                                                       3.5
#
#                                                                 2  \
# asin                                                   616719923X
# review_year                                                  2013
# review_month                                                   10
# review_day                                                      8
# timestamp                                              2013-10-08
# helpful                                                    [3, 4]
# overall                                                       4.0
# reviewText      Really good. Great gift for any fan of green t...
# reviewTime                                             10 8, 2013
# reviewerID                                         A27IQHDZFQFNGG
# reviewerName                                              Caitlin
# summary                                                      Yum!
# unixReviewTime                                         1381190400
# weight                                                          1
# reviews                                                         3
# average                                                  3.666667
#
#                                                                 3  \
# asin                                                   616719923X
# review_year                                                  2013
# review_month                                                    5
# review_day                                                     20
# timestamp                                              2013-05-20
# helpful                                                    [0, 0]
# overall                                                       5.0
# reviewText      I had never had it before, was curious to see ...
# reviewTime                                            05 20, 2013
# reviewerID                                         A31QY5TASILE89
# reviewerName                                         DebraDownSth
# summary                                    Unexpected flavor meld
# unixReviewTime                                         1369008000
# weight                                                          1
# reviews                                                         4
# average                                                       4.0
#
#                                                                 4
# asin                                                   616719923X
# review_year                                                  2013
# review_month                                                    5
# review_day                                                     26
# timestamp                                              2013-05-26
# helpful                                                    [1, 2]
# overall                                                       4.0
# reviewText      I've been looking forward to trying these afte...
# reviewTime                                            05 26, 2013
# reviewerID                                         A2LWK003FFMCI5
# reviewerName                                             Diana X.
# summary         Not a very strong tea flavor, but still yummy ...
# unixReviewTime                                         1369526400
# weight                                                          1
# reviews                                                         5
# average                                                       4.0

# %%
fml = 'overall ~ reviews + average'
robust = smf.ols(
    fml, data=df).fit(
        cov_type='cluster', 
        cov_kwds={'groups': np.array(df['asin'])})

# %%
print(robust.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                 3.159e+04
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):               0.00
# Time:                        22:26:17   Log-Likelihood:            -2.0210e+05
# No. Observations:              151254   AIC:                         4.042e+05
# Df Residuals:                  151251   BIC:                         4.042e+05
# Df Model:                           2
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0141      0.019     -0.731      0.464      -0.052       0.024
# reviews    -7.404e-05   4.52e-05     -1.637      0.102      -0.000    1.46e-05
# average        1.0032      0.004    243.524      0.000       0.995       1.011
# ==============================================================================
# Omnibus:                    28401.591   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54895.281
# Skew:                          -1.153   Prob(JB):                         0.00
# Kurtosis:                       4.842   Cond. No.                         670.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# ## discrete choice models

# %%
# low rating 
# 1. create a new variable called very_low and initially assign it to zero 
df.loc[:, "very_low"] = 0

# 2. when overall is equal to 1 then it is actually ver low
df.loc[df["overall"] == 1, "very_low"] = 1

# %%
fml = "very_low ~ reviews + average"
from statsmodels.formula.api import logit
robust = logit(fml, data=df).fit()
print(robust.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.134610
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               very_low   No. Observations:               151254
# Model:                          Logit   Df Residuals:                   151251
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 09 Oct 2022   Pseudo R-squ.:                  0.1701
# Time:                        22:27:57   Log-Likelihood:                -20360.
# converged:                       True   LL-Null:                       -24534.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3637      0.072     46.619      0.000       3.222       3.505
# reviews       -0.0011      0.000     -5.586      0.000      -0.001      -0.001
# average       -1.6581      0.019    -86.329      0.000      -1.696      -1.620
# ==============================================================================

# %% [markdown]
# ## count models

# %% [markdown]
# $ reviews = \alpha + \beta_{1} * average + \mu $

# %%
# formal 
fml = 'reviews ~ average' 
from statsmodels.formula.api import poisson
poisson = smf.poisson(fml, data=df).fit()
print(poisson.summary())
